# %%
import pandas as pd

# for spatial data
import geopandas as gpd

# for plotting
import matplotlib.pyplot as plt
# for basemaps
import contextily as ctx

import folium
from folium.plugins import MarkerCluster
import pandas as pd

import plotly.express as px

# %%
buffer=gpd.read_file("buffer_plot.geojson")
ethindex=gpd.read_file("ethnicityindex.geojson")

# %%
buffer_wm=buffer.to_crs(epsg=4326)
ethindex_wm=ethindex.to_crs(epsg=4326)

# %%
buffer
# Out:
#                Station         City Code  TOD County Marker  \
# 0                ASHBY     Berkeley  BKY  Yes    ALA      D
# 1            MACARTHUR      Oakland  OAK  Yes    ALA      D
# 2              HAYWARD      Hayward  HAY  Yes    ALA      D
# 3        SOUTH HAYWARD      Hayward  HAY  Yes    ALA      D
# 4            FRUITVALE      Oakland  OAK  Yes    ALA      D
# 5       NORTH BERKELEY     Berkeley  BKY   No    ALA      o
# 6  19TH STREET/OAKLAND      Oakland  OAK   No    ALA      o
# 7             BAY FAIR  San Leandro  SAN   No    ALA      o
# 8           UNION CITY   Union City  UNC   No    ALA      o
# 9         LAKE MERRITT      Oakland  OAK   No    ALA      o
#
#                                       buffer_polygon  Index 2019  Index 2013  \
# 0  POLYGON ((563770.9742351742 4188779.586837385,...    0.807620    0.779275
# 1  POLYGON ((563693.8852295046 4186061.965723997,...    0.798501    0.764635
# ...

# %%
maps = folium.Map(location = [37.8,-121.870118961256], tiles = "CartoDB positron", zoom_start = 11)

for _, r in gdf_cr.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    geo_j = folium.GeoJson(data=gdf_cr,
                           style_function=lambda x: {'fillColor': 'orange'})
    folium.Popup(r['Station']).add_to(geo_j)
    geo_j.add_to(maps)
maps

# %%
maps = folium.Map(location = [37.766429,-122.057218], tiles = "CartoDB positron", zoom_start = 10)

folium.Choropleth(
    geo_data=buffer,
    name="choropleth",
    data=buffer,
    columns=["Station", "Index 2019"],
    key_on="feature.Station",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)",
).add_to(maps)

maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
fig = px.choropleth_mapbox(buffer_em, locations='geometry', color='Station',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                           zoom=3, center = {"lat": 37.666429, "lon": -122.057218},
                           opacity=0.5,
                           #labels={'Station':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_805/3417102066.py in <module>
# ----> 1 fig = px.choropleth_mapbox(buffer_em, locations='geometry', color='Station',
#       2                            color_continuous_scale="Viridis",
#       3                            range_color=(0, 12),
#       4                            mapbox_style="carto-positron",
#       5                            zoom=3, center = {"lat": 37.666429, "lon": -122.057218},
#
# NameError: name 'buffer_em' is not defined
