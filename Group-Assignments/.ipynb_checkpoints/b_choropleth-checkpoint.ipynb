# %% [markdown]
# Choropleth Mapping of Ethnicity Index

# %%
# for general data wrangling tasks
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd

import matplotlib.pyplot as plt

import contextily as ctx
# Build the choropleth
import plotly.express as px

import base64
from io import BytesIO

# %%
ethdf=gpd.read_file("ethnicityindex.geojson")
stadf=gpd.read_file("stations.geojson")

# %%
tod=stadf[stadf['TOD']=='Yes']
ntod=stadf[stadf['TOD']=='No']
ethdf_wb = ethdf.to_crs(epsg=3857)
stadf_wb = stadf.to_crs(epsg=3857)
tod_wb = tod.to_crs(epsg=3857)
ntod_wb = ntod.to_crs(epsg=3857)

# %%
minx, miny, maxx, maxy = ethdf_wb.geometry.total_bounds

# %%
fig, ax = plt.subplots(figsize=(15,20))

# block groups
ethdf_wb.plot(ax=ax, # this puts it in the ax plot
        color='gray', 
        edgecolor='white',
        alpha=0.5)

ethdf_wb.plot(ax=ax,
              column = 'iqv_2013_sq',
              cmap='OrRd', 
              edgecolor='white',
              alpha=0.8,
            #scheme='natural',
           # classification_kwds={'bins':[0.25,0.50,0.75,1]},
              linewidth=0.3,
              legend=True,
              legend_kwds={'label':"Diversity Index",'aspect':'equal'})

tod_wb.plot(ax=ax,
         color = 'white',
         marker = "D",
         markersize = 15,
         label = ntod.Station)

ntod_wb.plot(ax=ax,
         color = 'yellow',
         marker = "D",
         markersize = 25,
         label = ntod.Station)

ax.set_xlim(minx-500, maxx-1000) 
ax.set_ylim(miny-500, maxy+500)
ax.axis('off')
ax.set_title("Ethnic Diversity in Alameda County (2013)",fontsize=15,pad=18)

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
tmpfile = BytesIO()
fig.savefig(tmpfile, format='png')
encoded = base64.b64encode(tmpfile.getvalue()).decode('utf-8')

html = 'Some html head' + '<img src=\'data:image/png;base64,{}\'>'.format(encoded) + 'Some more html'

with open('htmls/ethnic_choropleth_2013.html','w') as f:
    f.write(html)

# %%
fig, ax = plt.subplots(figsize=(15,20))

# block groups
ethdf_wb.plot(ax=ax, # this puts it in the ax plot
        color='gray', 
        edgecolor='white',
        alpha=0.5)

ethdf_wb.plot(ax=ax,
              column = 'iqv_2019_sq',
              cmap='OrRd', 
              edgecolor='white',
              alpha=0.8,
              linewidth=0.3,
              legend=True,
              legend_kwds={'label':"Diversity Index",'aspect':'equal'})

tod_wb.plot(ax=ax,
         color = 'white',
         marker = "D",
         markersize = 15,
         label = ntod['Station'])

ntod_wb.plot(ax=ax,
         color = 'yellow',
         marker = "D",
         markersize = 25,
         label = ntod['Station'])

ax.set_xlim(minx - 500, maxx - 1000) 
ax.set_ylim(miny - 500, maxy + 500)
ax.axis('off')
ax.set_title("Ethnic Diversity in Alameda County (2019)",fontsize=15,pad=18)

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
tmpfile = BytesIO()
fig.savefig(tmpfile, format='png')
encoded = base64.b64encode(tmpfile.getvalue()).decode('utf-8')

html = 'Some html head' + '<img src=\'data:image/png;base64,{}\'>'.format(encoded) + 'Some more html'

with open('htmls/ethnic_choropleth_2019.html','w') as f:
    f.write(html)

# %%
ethdf_wb.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 7433 entries, 0 to 7432
# Data columns (total 60 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   GEOID_left                                                            7433 non-null   object
#  1   NAME_left                                                             7433 non-null   object
#  2   Total_2019                                                            7433 non-null   float64
#  3   Non Hispanic_2019                                                     7433 non-null   float64
#  4   Non Hispanic White_2019                                               7433 non-null   float64
#  5   Non Hispanic Black_2019                                               7433 non-null   float64
#  6   Non Hispanic American Indian and Alaska Native_2019                   7433 non-null   float64
#  7   Non Hispanic Asian_2019                                               7433 non-null   float64
#  8   Non Hispanic Native Hawaiian and Other Pacific Islander_2019          7433 non-null   float64
#  9   Non Hispanic Some other race_2019                                     7433 non-null   float64
#  10  Non Hispanic Two or more races_2019                                   7433 non-null   float64
#  11  Hispanic_2019                                                         7433 non-null   float64
#  12  Percent Total_2019                                                    7389 non-null   float64
#  13  Percent Non Hispanic_2019                                             7389 non-null   float64
#  14  Percent Non Hispanic White_2019                                       7389 non-null   float64
#  15  Percent Non Hispanic Black_2019                                       7389 non-null   float64
#  16  Percent Non Hispanic American Indian and Alaska Native_2019           7389 non-null   float64
#  17  Percent Non Hispanic Asian_2019                                       7389 non-null   float64
#  18  Percent Non Hispanic Native Hawaiian and Other Pacific Islander_2019  7389 non-null   float64
#  19  Percent Non Hispanic Some other race_2019                             7389 non-null   float64
#  20  Percent Non Hispanic Two or more races_2019                           7389 non-null   float64
#  21  Percent Hispanic_2019                                                 7389 non-null   float64
#  22  index_right                                                           7433 non-null   int64
#  23  GEOID_right                                                           7433 non-null   object
#  24  Total_2013                                                            7433 non-null   float64
#  25  Non Hispanic_2013                                                     7433 non-null   float64
#  26  Non Hispanic White_2013                                               7433 non-null   float64
#  27  Non Hispanic Black_2013                                               7433 non-null   float64
#  28  Non Hispanic American Indian and Alaska Native_2013                   7433 non-null   float64
#  29  Non Hispanic Asian_2013                                               7433 non-null   float64
#  30  Non Hispanic Native Hawaiian and Other Pacific Islander_2013          7433 non-null   float64
#  31  Non Hispanic Some other race_2013                                     7433 non-null   float64
#  32  Non Hispanic Two or more races_2013                                   7433 non-null   float64
#  33  Hispanic_2013                                                         7433 non-null   float64
#  34  NAME_right                                                            7433 non-null   object
#  35  Percent Total_2013                                                    7405 non-null   float64
#  36  Percent Non Hispanic_2013                                             7405 non-null   float64
#  37  Percent Non Hispanic White_2013                                       7405 non-null   float64
#  38  Percent Non Hispanic Black_2013                                       7405 non-null   float64
#  39  Percent Non Hispanic American Indian and Alaska Native_2013           7405 non-null   float64
#  40  Percent Non Hispanic Asian_2013                                       7405 non-null   float64
#  41  Percent Non Hispanic Native Hawaiian and Other Pacific Islander_2013  7405 non-null   float64
#  42  Percent Non Hispanic Some other race_2013                             7405 non-null   float64
#  43  Percent Non Hispanic Two or more races_2013                           7405 non-null   float64
#  44  Percent Hispanic_2013                                                 7405 non-null   float64
#  45  Total_change                                                          7405 non-null   float64
#  46  Non Hispanic_change                                                   7405 non-null   float64
#  47  Non Hispanic White_change                                             7325 non-null   float64
#  48  Non Hispanic Black_change                                             6496 non-null   float64
#  49  Non Hispanic American Indian and Alaska Native_change                 1861 non-null   float64
#  50  Non Hispanic Asian_change                                             7251 non-null   float64
#  51  Non Hispanic Native Hawaiian and Other Pacific Islander_change        1968 non-null   float64
#  52  Non Hispanic Some other race_change                                   1148 non-null   float64
#  53  Non Hispanic Two or more races_change                                 6359 non-null   float64
#  54  Hispanic_change                                                       7300 non-null   float64
#  55  perc_2019_sq                                                          7389 non-null   float64
#  56  iqv_2019_sq                                                           7389 non-null   float64
#  57  perc_2013_sq                                                          7405 non-null   float64
#  58  iqv_2013_sq                                                           7405 non-null   float64
#  59  geometry                                                              7433 non-null   geometry
# dtypes: float64(54), geometry(1), int64(1), object(4)
# memory usage: 3.4+ MB

# %%
ethchange_wb=ethdf_wb[['GEOID_left' ,'NAME_left','iqv_2019_sq','iqv_2013_sq','geometry']]

# %%
ethchange_wb['index_change']=((ethchange_wb['iqv_2019_sq']-ethchange_wb['iqv_2013_sq'])/ethchange_wb['iqv_2013_sq'])*100

# %%
ethchange_wb.sample(10)
# Out:
#         GEOID_left                   NAME_left  iqv_2019_sq  iqv_2013_sq  \
# 6088  060014428001  Block Group 1, Alameda, CA     0.752798     0.818352
# 2582  060014096004  Block Group 4, Alameda, CA     0.679838     0.454851
# 1653  060014072002  Block Group 2, Alameda, CA     0.675184     0.422403
# 2102  060014076003  Block Group 3, Alameda, CA     0.714660     0.652859
# 4363  060014328002  Block Group 2, Alameda, CA     0.741254     0.726300
# 5264  060014430021  Block Group 1, Alameda, CA     0.806009     0.292763
# 1141  060014048001  Block Group 1, Alameda, CA     0.801027     0.431792
# 3163  060014251031  Block Group 1, Alameda, CA     0.766351     0.796926
# 6823  060014502003  Block Group 3, Alameda, CA     0.720503     0.610025
# 5155  060014366021  Block Group 1, Alameda, CA     0.742932     0.731914
#
#                                                geometry  index_change
# 6088  MULTIPOLYGON (((-13581234.023 4513218.673, -13...     -8.010446
# 2582  MULTIPOLYGON (((-13600550.404 4544407.926, -13...     49.463849
# 1653  MULTIPOLYGON (((-13605563.343 4547726.055, -13...     59.843467
# 2102  MULTIPOLYGON (((-13603717.888 4548151.952, -13...      9.466228
# 4363  MULTIPOLYGON (((-13596383.938 4541319.849, -13...      2.058852
# 5264  MULTIPOLYGON (((-13577097.168 4510843.860, -13...    175.310887
# 1141  MULTIPOLYGON (((-13605048.156 4551263.047, -13...     85.512076
# 3163  MULTIPOLYGON (((-13613821.357 4558070.666, -13...     -3.836515
# 6823  MULTIPOLYGON (((-13571673.905 4539435.386, -13...     18.110399
# 5155  MULTIPOLYGON (((-13591281.275 4529705.769, -13...      1.505408

# %%
ethchange_wb.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 7433 entries, 0 to 7432
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GEOID_left    7433 non-null   object
#  1   NAME_left     7433 non-null   object
#  2   iqv_2019_sq   7389 non-null   float64
#  3   iqv_2013_sq   7405 non-null   float64
#  4   geometry      7433 non-null   geometry
#  5   index_change  7368 non-null   float64
# dtypes: float64(3), geometry(1), object(2)
# memory usage: 348.5+ KB

# %%
ethchange_wb=ethchange_wb.dropna()

# %%
ethchange_wb.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 7368 entries, 0 to 7432
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GEOID_left    7368 non-null   object
#  1   NAME_left     7368 non-null   object
#  2   iqv_2019_sq   7368 non-null   float64
#  3   iqv_2013_sq   7368 non-null   float64
#  4   geometry      7368 non-null   geometry
#  5   index_change  7368 non-null   float64
# dtypes: float64(3), geometry(1), object(2)
# memory usage: 402.9+ KB

# %%
fig, ax = plt.subplots(figsize=(15,20))

# block groups
ethchange_wb.plot(ax=ax, # this puts it in the ax plot
        color='gray', 
        edgecolor='white',
        alpha=0.5)

ethchange_wb.plot(ax=ax,
                  column = ethchange_wb['index_change'],
                  cmap='RdYlBu',  
                  edgecolor='white',
                  alpha=0.8,
                  linewidth=0.3,
                  scheme='user_defined',
                  classification_kwds={'bins':[-100,-50,0,50,100]},
                  legend=True,
              #legend_kwds={'label':"Diversity Index"}
                 )

tod_wb.plot(ax=ax,
         color = 'white',
         marker = "D",
         markersize = 15,
         label = ntod['Station'])

ntod_wb.plot(ax=ax,
         color = 'yellow',
         marker = "D",
         markersize = 25,
         label = ntod['Station'])

ax.set_xlim(minx - 500, maxx - 1000) 
ax.set_ylim(miny - 500, maxy + 500)
ax.axis('off')
ax.set_title("Change in Ethnic Diversity in Alameda County (2013 to 2019)",fontsize=15,pad=18)

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)
# Out:
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py:860: RuntimeWarning: invalid value encountered in subtract
#   css = yc - yc.mean()
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py:891: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 - self.adcm / adam

# %%
tmpfile = BytesIO()
fig.savefig(tmpfile, format='png')
encoded = base64.b64encode(tmpfile.getvalue()).decode('utf-8')

html = 'Some html head' + '<img src=\'data:image/png;base64,{}\'>'.format(encoded) + 'Some more html'

with open('htmls/ethnicchange_choropleth.html','w') as f:
    f.write(html)
