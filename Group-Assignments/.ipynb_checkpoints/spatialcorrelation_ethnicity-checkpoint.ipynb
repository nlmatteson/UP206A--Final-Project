# %% [markdown]
# # Group Assignment #3: A Clean Notebook
#
# ## Compilation of Work
#
# Work to download and clean data for blockgroups.

# %%
# for general data wrangling tasks
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ## 2019 block group data for alameda county

# %%
b2019 = gpd.read_file("acs2019_5yr_B03002_15000US060014094001.geojson")

# %%
b2019.head()
# Out:
#                  geoid                        name  B03002001  \
# 0         05000US06001          Alameda County, CA  1656754.0
# 1  15000US060014001001  Block Group 1, Alameda, CA     3120.0
# 2  15000US060014002001  Block Group 1, Alameda, CA      990.0
# 3  15000US060014002002  Block Group 2, Alameda, CA     1017.0
# 4  15000US060014003001  Block Group 1, Alameda, CA     1134.0
#
#    B03002001, Error  B03002002  B03002002, Error  B03002003  B03002003, Error  \
# 0               0.0  1285735.0               0.0   520447.0             487.0
# 1             208.0     3002.0             191.0     2317.0             235.0
# 2             138.0      894.0             129.0      761.0             129.0
# 3             123.0      939.0             129.0      714.0             116.0
# 4             238.0     1059.0             241.0      735.0             215.0
#
#    B03002004  B03002004, Error  ...  B03002017, Error  B03002018  \
# ...

# %%
b2019=b2019.drop([0])

# %%
b2019.head()
# Out:
#                  geoid                        name  B03002001  \
# 1  15000US060014001001  Block Group 1, Alameda, CA     3120.0
# 2  15000US060014002001  Block Group 1, Alameda, CA      990.0
# 3  15000US060014002002  Block Group 2, Alameda, CA     1017.0
# 4  15000US060014003001  Block Group 1, Alameda, CA     1134.0
# 5  15000US060014003002  Block Group 2, Alameda, CA     1237.0
#
#    B03002001, Error  B03002002  B03002002, Error  B03002003  B03002003, Error  \
# 1             208.0     3002.0             191.0     2317.0             235.0
# 2             138.0      894.0             129.0      761.0             129.0
# 3             123.0      939.0             129.0      714.0             116.0
# 4             238.0     1059.0             241.0      735.0             215.0
# 5             263.0     1139.0             255.0     1008.0             248.0
#
#    B03002004  B03002004, Error  ...  B03002017, Error  B03002018  \
# ...

# %%
b2019=b2019.reset_index()

# %%
b2019.head()
# Out:
#    index                geoid                        name  B03002001  \
# 0      1  15000US060014001001  Block Group 1, Alameda, CA     3120.0
# 1      2  15000US060014002001  Block Group 1, Alameda, CA      990.0
# 2      3  15000US060014002002  Block Group 2, Alameda, CA     1017.0
# 3      4  15000US060014003001  Block Group 1, Alameda, CA     1134.0
# 4      5  15000US060014003002  Block Group 2, Alameda, CA     1237.0
#
#    B03002001, Error  B03002002  B03002002, Error  B03002003  B03002003, Error  \
# 0             208.0     3002.0             191.0     2317.0             235.0
# 1             138.0      894.0             129.0      761.0             129.0
# 2             123.0      939.0             129.0      714.0             116.0
# 3             238.0     1059.0             241.0      735.0             215.0
# 4             263.0     1139.0             255.0     1008.0             248.0
#
#    B03002004  ...  B03002017, Error  B03002018  B03002018, Error  B03002019  \
# ...

# %%
list(b2019)
# Out:
# ['index',
#  'geoid',
#  'name',
#  'B03002001',
#  'B03002001, Error',
#  'B03002002',
#  'B03002002, Error',
#  'B03002003',
#  'B03002003, Error',
#  'B03002004',
#  'B03002004, Error',
#  'B03002005',
#  'B03002005, Error',
#  'B03002006',
#  'B03002006, Error',
#  'B03002007',
#  'B03002007, Error',
#  'B03002008',
#  'B03002008, Error',
#  'B03002009',
#  'B03002009, Error',
#  'B03002010',
#  'B03002010, Error',
#  'B03002011',
#  'B03002011, Error',
#  'B03002012',
#  'B03002012, Error',
#  'B03002013',
#  'B03002013, Error',
#  'B03002014',
#  'B03002014, Error',
#  'B03002015',
#  'B03002015, Error',
#  'B03002016',
#  'B03002016, Error',
#  'B03002017',
#  'B03002017, Error',
#  'B03002018',
#  'B03002018, Error',
#  'B03002019',
#  'B03002019, Error',
#  'B03002020',
#  'B03002020, Error',
#  'B03002021',
#  'B03002021, Error',
#  'geometry']

# %%
columns_to_keep = ['geoid',
                   'name',
                   'B03002001',
                   'B03002002',
                   'B03002003',
                   'B03002004',
                   'B03002005',
                   'B03002006',
                   'B03002007',
                   'B03002008',
                   'B03002009',
                   'B03002012',
                   'geometry']

# %%
block2019=b2019[columns_to_keep]

# %%
block2019.head()
# Out:
#                  geoid                        name  B03002001  B03002002  \
# 0  15000US060014001001  Block Group 1, Alameda, CA     3120.0     3002.0
# 1  15000US060014002001  Block Group 1, Alameda, CA      990.0      894.0
# 2  15000US060014002002  Block Group 2, Alameda, CA     1017.0      939.0
# 3  15000US060014003001  Block Group 1, Alameda, CA     1134.0     1059.0
# 4  15000US060014003002  Block Group 2, Alameda, CA     1237.0     1139.0
#
#    B03002003  B03002004  B03002005  B03002006  B03002007  B03002008  \
# 0     2317.0      107.0        0.0      391.0        0.0        0.0
# 1      761.0       13.0        4.0       41.0        0.0        0.0
# 2      714.0       39.0        0.0      130.0        0.0        0.0
# 3      735.0        0.0        0.0      274.0        0.0        0.0
# 4     1008.0       18.0        0.0      113.0        0.0        0.0
#
#    B03002009  B03002012                                           geometry
# ...

# %%
block2019['geoid'] = block2019['geoid'].str.replace('15000US','')
block2019.head()
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#           geoid                        name  B03002001  B03002002  B03002003  \
# 0  060014001001  Block Group 1, Alameda, CA     3120.0     3002.0     2317.0
# 1  060014002001  Block Group 1, Alameda, CA      990.0      894.0      761.0
# 2  060014002002  Block Group 2, Alameda, CA     1017.0      939.0      714.0
# 3  060014003001  Block Group 1, Alameda, CA     1134.0     1059.0      735.0
# 4  060014003002  Block Group 2, Alameda, CA     1237.0     1139.0     1008.0
#
#    B03002004  B03002005  B03002006  B03002007  B03002008  B03002009  \
# ...

# %%
block2019.columns = ['GEOID',
 'NAME',
 'Total',
 'Non Hispanic',
 'Non Hispanic White',
 'Non Hispanic Black',
 'Non Hispanic American Indian and Alaska Native',
 'Non Hispanic Asian',
 'Non Hispanic Native Hawaiian and Other Pacific Islander',
 'Non Hispanic Some other race',
 'Non Hispanic Two or more races',
 'Hispanic',
 'geometry']

# %%
block2019.head()
# Out:
#           GEOID                        NAME   Total  Non Hispanic  \
# 0  060014001001  Block Group 1, Alameda, CA  3120.0        3002.0
# 1  060014002001  Block Group 1, Alameda, CA   990.0         894.0
# 2  060014002002  Block Group 2, Alameda, CA  1017.0         939.0
# 3  060014003001  Block Group 1, Alameda, CA  1134.0        1059.0
# 4  060014003002  Block Group 2, Alameda, CA  1237.0        1139.0
#
#    Non Hispanic White  Non Hispanic Black  \
# 0              2317.0               107.0
# 1               761.0                13.0
# 2               714.0                39.0
# 3               735.0                 0.0
# 4              1008.0                18.0
#
#    Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 0                                             0.0               391.0
# 1                                             4.0                41.0
# 2                                             0.0               130.0
# ...

# %% [markdown]
# ## 2013 block group data for alameda county

# %%
b2013 = gpd.read_file("ACSDT5Y2013.B03002_data_with_overlays_2022-02-21T160847.csv")

# %%
b2013.head()
# Out:
#        B03002_001E             B03002_001M  \
# 0  Estimate!!Total  Margin of Error!!Total
# 1             3353                     332
# 2             1031                     151
# 3              913                     147
# 4             1447                     654
#
#                                B03002_002E  \
# 0  Estimate!!Total!!Not Hispanic or Latino
# 1                                     3101
# 2                                      870
# 3                                      860
# 4                                     1392
#
#                                       B03002_002M  \
# 0  Margin of Error!!Total!!Not Hispanic or Latino
# 1                                             293
# 2                                             116
# 3                                             144
# 4                                             651
#
#                                          B03002_003E  \
# 0  Estimate!!Total!!Not Hispanic or Latino!!White...
# ...

# %%
b2013.tail()
# Out:
#      B03002_001E B03002_001M B03002_002E B03002_002M B03002_003E B03002_003M  \
# 1043         947         327         675         282         575         221
# 1044          43          19          43          19          43          19
# 1045         105          48          55          21          44          24
# 1046         416          70         387          67         197          54
# 1047           0          12           0          12           0          12
#
#      B03002_004E B03002_004M B03002_005E B03002_005M  ... B03002_018M  \
# 1043           0          12          15          25  ...          12
# 1044           0          12           0          12  ...          12
# 1045           0          12           0          12  ...          49
# 1046          69          36           0          12  ...          12
# 1047           0          12           0          12  ...          12
#
#      B03002_019E B03002_019M B03002_020E B03002_020M B03002_021E B03002_021M  \
# ...

# %%
b2013=b2013.drop([1047])

# %%
b2013.tail()
# Out:
#      B03002_001E B03002_001M B03002_002E B03002_002M B03002_003E B03002_003M  \
# 1042        1740         308        1458         276        1379         271
# 1043         947         327         675         282         575         221
# 1044          43          19          43          19          43          19
# 1045         105          48          55          21          44          24
# 1046         416          70         387          67         197          54
#
#      B03002_004E B03002_004M B03002_005E B03002_005M  ... B03002_018M  \
# 1042           0          12           0          12  ...          49
# 1043           0          12          15          25  ...          12
# 1044           0          12           0          12  ...          12
# 1045           0          12           0          12  ...          49
# 1046          69          36           0          12  ...          12
#
#      B03002_019E B03002_019M B03002_020E B03002_020M B03002_021E B03002_021M  \
# ...

# %%
list(b2013)
# Out:
# ['B03002_001E',
#  'B03002_001M',
#  'B03002_002E',
#  'B03002_002M',
#  'B03002_003E',
#  'B03002_003M',
#  'B03002_004E',
#  'B03002_004M',
#  'B03002_005E',
#  'B03002_005M',
#  'B03002_006E',
#  'B03002_006M',
#  'B03002_007E',
#  'B03002_007M',
#  'B03002_008E',
#  'B03002_008M',
#  'B03002_009E',
#  'B03002_009M',
#  'B03002_010E',
#  'B03002_010M',
#  'B03002_011E',
#  'B03002_011M',
#  'B03002_012E',
#  'B03002_012M',
#  'B03002_013E',
#  'B03002_013M',
#  'B03002_014E',
#  'B03002_014M',
#  'B03002_015E',
#  'B03002_015M',
#  'B03002_016E',
#  'B03002_016M',
#  'B03002_017E',
#  'B03002_017M',
#  'B03002_018E',
#  'B03002_018M',
#  'B03002_019E',
#  'B03002_019M',
#  'B03002_020E',
#  'B03002_020M',
#  'B03002_021E',
#  'B03002_021M',
#  'GEO_ID',
#  'NAME',
#  'geometry']

# %%
columns_to_keep2= ['B03002_001E',
                   'B03002_002E',
                   'B03002_003E',
                   'B03002_004E',
                   'B03002_005E',
                   'B03002_006E',
                   'B03002_007E',
                   'B03002_008E',
                   'B03002_009E',
                   'B03002_012E',
                   'GEO_ID',
                   'NAME',
                   'geometry']

# %%
block2013=b2013[columns_to_keep2]

# %%
block2013.head()
# Out:
#        B03002_001E                              B03002_002E  \
# 0  Estimate!!Total  Estimate!!Total!!Not Hispanic or Latino
# 1             3353                                     3101
# 2             1031                                      870
# 3              913                                      860
# 4             1447                                     1392
#
#                                          B03002_003E  \
# 0  Estimate!!Total!!Not Hispanic or Latino!!White...
# 1                                               2141
# 2                                                727
# 3                                                640
# 4                                                891
#
#                                          B03002_004E  \
# 0  Estimate!!Total!!Not Hispanic or Latino!!Black...
# 1                                                165
# 2                                                  0
# 3                                                 40
# ...

# %%
block2013=block2013.drop([0])

# %%
block2013.reset_index()
# Out:
#       index B03002_001E B03002_002E B03002_003E B03002_004E B03002_005E  \
# 0         1        3353        3101        2141         165           0
# 1         2        1031         870         727           0           0
# 2         3         913         860         640          40           0
# 3         4        1447        1392         891         128           0
# 4         5         938         840         594          74          15
# ...     ...         ...         ...         ...         ...         ...
# 1041   1042        1740        1458        1379           0           0
# 1042   1043         947         675         575           0          15
# 1043   1044          43          43          43           0           0
# 1044   1045         105          55          44           0           0
# 1045   1046         416         387         197          69           0
#
#      B03002_006E B03002_007E B03002_008E B03002_009E B03002_012E  \
# ...

# %%
block2013.columns = [
 'Total',
 'Non Hispanic',
 'Non Hispanic White',
 'Non Hispanic Black',
 'Non Hispanic American Indian and Alaska Native',
 'Non Hispanic Asian',
 'Non Hispanic Native Hawaiian and Other Pacific Islander',
 'Non Hispanic Some other race',
 'Non Hispanic Two or more races',
 'Hispanic',
 'GEOID',
 'NAME',
 'geometry']

# %%
block2013.head()
# Out:
#   Total Non Hispanic Non Hispanic White Non Hispanic Black  \
# 1  3353         3101               2141                165
# 2  1031          870                727                  0
# 3   913          860                640                 40
# 4  1447         1392                891                128
# 5   938          840                594                 74
#
#   Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 1                                              0                658
# 2                                              0                100
# 3                                              0                101
# 4                                              0                318
# 5                                             15                105
#
#   Non Hispanic Native Hawaiian and Other Pacific Islander  \
# 1                                                  0
# 2                                                  0
# ...

# %%
block2013['GEOID'] = block2013['GEOID'].str.replace('1500000US','')
block2013.head()
# Out:
#   Total Non Hispanic Non Hispanic White Non Hispanic Black  \
# 1  3353         3101               2141                165
# 2  1031          870                727                  0
# 3   913          860                640                 40
# 4  1447         1392                891                128
# 5   938          840                594                 74
#
#   Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 1                                              0                658
# 2                                              0                100
# 3                                              0                101
# 4                                              0                318
# 5                                             15                105
#
#   Non Hispanic Native Hawaiian and Other Pacific Islander  \
# 1                                                  0
# 2                                                  0
# ...

# %%
block2013=block2013[[
 'Total',
 'Non Hispanic',
 'Non Hispanic White',
 'Non Hispanic Black',
 'Non Hispanic American Indian and Alaska Native',
 'Non Hispanic Asian',
 'Non Hispanic Native Hawaiian and Other Pacific Islander',
 'Non Hispanic Some other race',
 'Non Hispanic Two or more races',
 'Hispanic',
 'GEOID',
 'NAME']]

# %%
block2013.head()
# Out:
#   Total Non Hispanic Non Hispanic White Non Hispanic Black  \
# 1  3353         3101               2141                165
# 2  1031          870                727                  0
# 3   913          860                640                 40
# 4  1447         1392                891                128
# 5   938          840                594                 74
#
#   Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 1                                              0                658
# 2                                              0                100
# 3                                              0                101
# 4                                              0                318
# 5                                             15                105
#
#   Non Hispanic Native Hawaiian and Other Pacific Islander  \
# 1                                                  0
# 2                                                  0
# ...

# %%
blockshape = gpd.read_file("2013_block/tl_2013_06_bg.shp")

# %%
blockshape.head()
# Out:
#   STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 0      06      025  940000        3  060259400003  Block Group 3  G5030
# 1      06      025  010800        2  060250108002  Block Group 2  G5030
# 2      06      025  010800        1  060250108001  Block Group 1  G5030
# 3      06      025  011100        3  060250111003  Block Group 3  G5030
# 4      06      073  010013        2  060730100132  Block Group 2  G5030
#
#   FUNCSTAT      ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S   12266442  680335  +32.7424027  -114.6675664
# 1        S   59331705       0  +32.7658550  -115.3923893
# 2        S  230656790       0  +32.8363463  -115.3514134
# 3        S    1209336       0  +32.7932442  -115.6903925
# 4        S     404606       0  +32.5564082  -117.0507980
#
#                                             geometry
# 0  POLYGON ((-114.72653 32.71824, -114.72639 32.7...
# 1  POLYGON ((-115.43082 32.73090, -115.43082 32.7...
# ...

# %%
blockshape.tail()
# Out:
#       STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 23207      06      113  010602        2  061130106022  Block Group 2  G5030
# 23208      06      113  010602        3  061130106023  Block Group 3  G5030
# 23209      06      113  011400        1  061130114001  Block Group 1  G5030
# 23210      06      113  011400        2  061130114002  Block Group 2  G5030
# 23211      06      113  010501        2  061130105012  Block Group 2  G5030
#
#       FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# 23207        S     349540        0  +38.5483345  -121.7365530
# 23208        S     598201        0  +38.5494135  -121.7306048
# 23209        S  243685259        0  +38.7914978  -121.9434365
# 23210        S  219220061  2549594  +38.8550515  -121.8698636
# 23211        S    2304988        0  +38.5341538  -121.7566773
#
#                                                 geometry
# 23207  POLYGON ((-121.73996 38.55141, -121.73974 38.5...
# ...

# %%
blockshape=blockshape[['GEOID', 'geometry']]

# %%
block2013v = blockshape.merge(block2013, on='GEOID')

# %%
block2013v.head()
# Out:
#           GEOID                                           geometry Total  \
# 0  060014403351  POLYGON ((-122.01845 37.59582, -122.01841 37.5...  2773
# 1  060014423012  POLYGON ((-121.96678 37.53030, -121.96678 37.5...  1371
# 2  060014060001  POLYGON ((-122.26735 37.78872, -122.26445 37.7...   753
# 3  060014337001  POLYGON ((-122.11467 37.68870, -122.11462 37.6...   931
# 4  060014364012  POLYGON ((-122.07302 37.67305, -122.07265 37.6...  2296
#
#   Non Hispanic Non Hispanic White Non Hispanic Black  \
# 0         2595                361                 51
# 1          990                339                 21
# 2          480                143                 45
# 3          376                241                 93
# 4         1800                878                363
#
#   Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 0                                             19               2022
# ...

# %%
block2013v.shape
# Out:
# (1046, 13)

# %%
block2013.shape
# Out:
# (1046, 12)

# %%
# for basemaps
import contextily as ctx

# For spatial statistics
import esda
from esda.moran import Moran, Moran_Local

import splot
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster,plot_moran_simulation

import libpysal as lps

# Graphics
import matplotlib.pyplot as plt
import plotly.express as px

# %%
block2013v.sort_values(by='Total').head(20)
# Out:
#              GEOID                                           geometry Total  \
# 851   060014511014  POLYGON ((-121.71878 37.67985, -121.71874 37.6...     0
# 128   060014100003  POLYGON ((-122.15170 37.75191, -122.15168 37.7...     0
# 34    060014090004  POLYGON ((-122.25550 37.72177, -122.25153 37.7...     0
# 1032  060014090002  POLYGON ((-122.22655 37.74684, -122.22651 37.7...     0
# 78    060014065002  POLYGON ((-122.21625 37.78833, -122.21597 37.7...  1000
# 488   060014272003  POLYGON ((-122.25530 37.77274, -122.25521 37.7...  1000
# 594   060014088002  POLYGON ((-122.20251 37.75608, -122.20217 37.7...  1000
# 341   060014077002  POLYGON ((-122.19932 37.77564, -122.19792 37.7...  1002
# 682   060014431022  POLYGON ((-121.92834 37.50680, -121.92833 37.5...  1003
# 582   060014055003  POLYGON ((-122.24665 37.79828, -122.24660 37.7...  1003
# 945   060014331042  POLYGON ((-122.14864 37.71970, -122.14792 37.7...  1004
# ...

# %%
block2013v.head()
# Out:
#           GEOID                                           geometry Total  \
# 0  060014403351  POLYGON ((-122.01845 37.59582, -122.01841 37.5...  2773
# 1  060014423012  POLYGON ((-121.96678 37.53030, -121.96678 37.5...  1371
# 2  060014060001  POLYGON ((-122.26735 37.78872, -122.26445 37.7...   753
# 3  060014337001  POLYGON ((-122.11467 37.68870, -122.11462 37.6...   931
# 4  060014364012  POLYGON ((-122.07302 37.67305, -122.07265 37.6...  2296
#
#   Non Hispanic Non Hispanic White Non Hispanic Black  \
# 0         2595                361                 51
# 1          990                339                 21
# 2          480                143                 45
# 3          376                241                 93
# 4         1800                878                363
#
#   Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 0                                             19               2022
# ...

# %%
block2013v.sort_values(by='Total').head()
# Out:
#              GEOID                                           geometry Total  \
# 851   060014511014  POLYGON ((-121.71878 37.67985, -121.71874 37.6...     0
# 128   060014100003  POLYGON ((-122.15170 37.75191, -122.15168 37.7...     0
# 34    060014090004  POLYGON ((-122.25550 37.72177, -122.25153 37.7...     0
# 1032  060014090002  POLYGON ((-122.22655 37.74684, -122.22651 37.7...     0
# 78    060014065002  POLYGON ((-122.21625 37.78833, -122.21597 37.7...  1000
#
#      Non Hispanic Non Hispanic White Non Hispanic Black  \
# 851             0                  0                  0
# 128             0                  0                  0
# 34              0                  0                  0
# 1032            0                  0                  0
# 78            789                 55                229
#
#      Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 851                                               0                  0
# ...

# %%
random_tract= block2013v.sample(1)

# %%
random_tract
# Out:
#             GEOID                                           geometry Total  \
# 879  060014283013  POLYGON ((-122.24889 37.73472, -122.24882 37.7...   626
#
#     Non Hispanic Non Hispanic White Non Hispanic Black  \
# 879          540                267                  0
#
#     Non Hispanic American Indian and Alaska Native Non Hispanic Asian  \
# 879                                              0                273
#
#     Non Hispanic Native Hawaiian and Other Pacific Islander  \
# 879                                                  0
#
#     Non Hispanic Some other race Non Hispanic Two or more races Hispanic  \
# 879                            0                              0       86
#
#                                                   NAME
# 879  Block Group 3, Census Tract 4283.01, Alameda C...

# %%
type(random_tract.iloc[0]['Non Hispanic'])
# Out:
# str

# %%
dtypes = ['Total', 
 'Non Hispanic',
 'Non Hispanic White',
 'Non Hispanic Black',
 'Non Hispanic American Indian and Alaska Native',
 'Non Hispanic Asian',
 'Non Hispanic Native Hawaiian and Other Pacific Islander',
 'Non Hispanic Some other race',
 'Non Hispanic Two or more races',
 'Hispanic']

# %%
for i in dtypes:
    block2013v[i]=block2013v[i].astype(float)

# %%
random_tract2 = block2013v.sample(1)

# %%
type(random_tract2.iloc[0]['Non Hispanic'])
# Out:
# numpy.float64

# %%
random_block=block2019.sample(1)

# %%
type(random_block.iloc[0]['Non Hispanic'])
# Out:
# numpy.float64

# %%
block2019.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1047 entries, 0 to 1046
# Data columns (total 13 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   GEOID                                                    1047 non-null   object
#  1   NAME                                                     1047 non-null   object
#  2   Total                                                    1047 non-null   float64
#  3   Non Hispanic                                             1047 non-null   float64
#  4   Non Hispanic White                                       1047 non-null   float64
#  5   Non Hispanic Black                                       1047 non-null   float64
#  6   Non Hispanic American Indian and Alaska Native           1047 non-null   float64
#  7   Non Hispanic Asian                                       1047 non-null   float64
# ...

# %%
block2013v.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1046 entries, 0 to 1045
# Data columns (total 13 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   GEOID                                                    1046 non-null   object
#  1   geometry                                                 1046 non-null   geometry
#  2   Total                                                    1046 non-null   float64
#  3   Non Hispanic                                             1046 non-null   float64
#  4   Non Hispanic White                                       1046 non-null   float64
#  5   Non Hispanic Black                                       1046 non-null   float64
#  6   Non Hispanic American Indian and Alaska Native           1046 non-null   float64
#  7   Non Hispanic Asian                                       1046 non-null   float64
# ...

# %%
def createpercentage(block):
    for x in dtypes:
        block[("Percent " + x)] = block[x]/block['Total']*100
        print(x, "Completed")

# %%
createpercentage(block2019)
# Out:
# Total Completed
# Non Hispanic Completed
# Non Hispanic White Completed
# Non Hispanic Black Completed
# Non Hispanic American Indian and Alaska Native Completed
# Non Hispanic Asian Completed
# Non Hispanic Native Hawaiian and Other Pacific Islander Completed
# Non Hispanic Some other race Completed
# Non Hispanic Two or more races Completed
# Hispanic Completed
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
createpercentage(block2013v)
# Out:
# Total Completed
# Non Hispanic Completed
# Non Hispanic White Completed
# Non Hispanic Black Completed
# Non Hispanic American Indian and Alaska Native Completed
# Non Hispanic Asian Completed
# Non Hispanic Native Hawaiian and Other Pacific Islander Completed
# Non Hispanic Some other race Completed
# Non Hispanic Two or more races Completed
# Hispanic Completed

# %%
block2019.head()
# Out:
#           GEOID                        NAME   Total  Non Hispanic  \
# 0  060014001001  Block Group 1, Alameda, CA  3120.0        3002.0
# 1  060014002001  Block Group 1, Alameda, CA   990.0         894.0
# 2  060014002002  Block Group 2, Alameda, CA  1017.0         939.0
# 3  060014003001  Block Group 1, Alameda, CA  1134.0        1059.0
# 4  060014003002  Block Group 2, Alameda, CA  1237.0        1139.0
#
#    Non Hispanic White  Non Hispanic Black  \
# 0              2317.0               107.0
# 1               761.0                13.0
# 2               714.0                39.0
# 3               735.0                 0.0
# 4              1008.0                18.0
#
#    Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 0                                             0.0               391.0
# 1                                             4.0                41.0
# 2                                             0.0               130.0
# ...

# %%
block2013v.head()
# Out:
#           GEOID                                           geometry   Total  \
# 0  060014403351  POLYGON ((-122.01845 37.59582, -122.01841 37.5...  2773.0
# 1  060014423012  POLYGON ((-121.96678 37.53030, -121.96678 37.5...  1371.0
# 2  060014060001  POLYGON ((-122.26735 37.78872, -122.26445 37.7...   753.0
# 3  060014337001  POLYGON ((-122.11467 37.68870, -122.11462 37.6...   931.0
# 4  060014364012  POLYGON ((-122.07302 37.67305, -122.07265 37.6...  2296.0
#
#    Non Hispanic  Non Hispanic White  Non Hispanic Black  \
# 0        2595.0               361.0                51.0
# 1         990.0               339.0                21.0
# 2         480.0               143.0                45.0
# 3         376.0               241.0                93.0
# 4        1800.0               878.0               363.0
#
#    Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 0                                            19.0              2022.0
# ...

# %%
col2019=list(block2019)

# %%
col2019

# %%
col2013=list(block2013v)

# %%
col2013

# %%
def add_year (block, year):
    for i in block:
        if "Hispanic" in i:
            i=i + "_" + year
            print("\'" + i + "\',")
        elif "Total" in i:
            i=i + "_" + year
            print("\'" + i + "\',")
        else:
            print("\'" + i + "\',")

# %%
add_year(col2019, "19")

# %%
add_year(col2013, "13")

# %%
c19=['GEOID',
'NAME',
'Total_19',
'Non Hispanic_19',
'Non Hispanic White_19',
'Non Hispanic Black_19',
'Non Hispanic American Indian and Alaska Native_19',
'Non Hispanic Asian_19',
'Non Hispanic Native Hawaiian and Other Pacific Islander_19',
'Non Hispanic Some other race_19',
'Non Hispanic Two or more races_19',
'Hispanic_19',
'geometry',
'Percent Total_19',
'Percent Non Hispanic_19',
'Percent Non Hispanic White_19',
'Percent Non Hispanic Black_19',
'Percent Non Hispanic American Indian and Alaska Native_19',
'Percent Non Hispanic Asian_19',
'Percent Non Hispanic Native Hawaiian and Other Pacific Islander_19',
'Percent Non Hispanic Some other race_19',
'Percent Non Hispanic Two or more races_19',
'Percent Hispanic_19',
[175]:

add_year(col2013, "13")
'GEOID'
'geometry'
'Total_13'
'Non Hispanic_13'
'Non Hispanic White_13'
'Non Hispanic Black_13'
'Non Hispanic American Indian and Alaska Native_13'
'Non Hispanic Asian_13'
'Non Hispanic Native Hawaiian and Other Pacific Islander_13'
'Non Hispanic Some other race_13'
'Non Hispanic Two or more races_13'
'Hispanic_13'
'NAME'
'Percent Total_13'
'Percent Non Hispanic_13'
'Percent Non Hispanic White_13'
'Percent Non Hispanic Black_13'
'Percent Non Hispanic American Indian and Alaska Native_13'
'Percent Non Hispanic Asian_13'
'Percent Non Hispanic Native Hawaiian and Other Pacific Islander_13'
'Percent Non Hispanic Some other race_13'
'Percent Non Hispanic Two or more races_13'
'Percent Hispanic_13']

# %%
block2019.columsn=c19

# %%
def renamecols(block, col):
    block.columns=col
    block.head()

# %%
renamecols(block2019, col2019)

# %%
block2019.head()
