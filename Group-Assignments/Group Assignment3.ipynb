# %% [markdown]
# # Group Assignment #3: A Clean Notebook
# ## Focus and Control Bart Stations: Adding a Function and a Loop
#
#
# For this week's assignment, we are going to clean the California Rail dataset so that it only includes our project's focus stations and control stations. We will also designate marker types for the stations to signify if they are control or not. Additionally, we will create a function that will print out the station name and whether it is a TOD project location or not. We will then loop through this function so that each of our ten stations (five focus and five control) will print out with this information.
#
# We'll first start by bringing in the necessary libraries and importing my data. Nicole already cleaned the California Rail dataset to get a downloadable variable of just our five focus stations in a previous assignment (week 4). We will load that datset in, but we will need to clean the original dataset again to get a variable that includes our control stations.

# %%
import pandas as pd # this is for regular data analysis
import geopandas as gpd # this is for geospatial analysis
import contextily as ctx # this is for basemaps
import matplotlib.pyplot as plt # this is for plotting
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
bart = gpd.read_file('Data/California_Rail_Stations.geojson')
bart.head()
# Out:
#    OBJECTID        LOCATION                    STATION CODE  \
# 0         1  Parking Garage  MONTEREY - Parking Garage    -
# 1         2      El Segundo                 EL SEGUNDO  ESG
# 2         3     Morgan Hill                MORGAN HILL  MHC
# 3         4  Amtrak Station           OAKLAND COLISEUM  OAC
# 4         5  Amtrak Station              SANTA BARBARA  SBA
#
#                                ADDRESS    ZIP PASS_OP  \
# 0  Tyler, between Del Monte & Franklin  93940
# 1             700 South Douglas Street  90245
# 2                   17200 Depot Street  95037
# 3             700 Seventy-third Avenue  94621  Amtrak
# 4                     209 State Street  93101  Amtrak
#
#                           PASS_NETWO COMM_OP COMM_NETWO  BUS_ROUTES  \
# 0                                                                55
# 1                                                                1c
# 2                                      PCJPB   Caltrain          55
# 3                   Capitol Corridor
# 4  Coast Starlight,Pacific Surfliner                     4,10,17,21
#
#              TRANSIT                   AIRPORT  STATION_TY INTERMODAL  DIST  \
# 0                                                        2          0     5
# 1                                                        2          0     7
# 2                                                        3          1     4
# 3    AC Transit,BART  AirBART connector to OAK           6          1     4
# 4  Santa Barbara MTD                                     5          1     5
#
#     CO                     geometry
# 0  MON  POINT (-121.89330 36.60033)
# 1   LA  POINT (-118.38342 33.90512)
# 2  SCL  POINT (-121.65053 37.12966)
# 3  ALA  POINT (-122.19820 37.75252)
# 4   SB  POINT (-119.69260 34.41430)

# %%
tod= gpd.read_file('focus_stations.geojson')
tod.head()
# Out:
#          STATION  OBJECTID LOCATION CODE ADDRESS ZIP COMM_NETWO  STATION_TY  \
# 0          ASHBY       215                         0       BART           1
# 1      MACARTHUR       217                         0       BART           1
# 2        HAYWARD       227                         0       BART           1
# 3  SOUTH HAYWARD       228                         0       BART           1
# 4      FRUITVALE       222                         0       BART           1
#
#    DIST   CO                     geometry
# 0     4  ALA  POINT (-122.27012 37.85321)
# 1     4  ALA  POINT (-122.26712 37.82871)
# 2     4  ALA  POINT (-122.08720 37.67012)
# 3     4  ALA  POINT (-122.05704 37.63448)
# 4     4  ALA  POINT (-122.22420 37.77456)

# %% [markdown]
# Great, everything loaded perfectly. We can immediately see the differences between the two datasets. "bart" has a bunch of columns we don't need and has all the rail stations in California. I'm also noticing that my "tod" variable has missing information. Apparently these stations did not have their location, code, address, or zip code. I'll make a note to clean up the columns so that we just have the station name, objectid, location (I'll fill in the city the station is in), code (I'll fill in an abbreviation of the station name), the comm_netwo, co (for county) and geometry.
#
# First things first though, I'm going to clean up the large dataset to only have our ten necessary stations.

# %%
# getting columns of dataset to start taking them out
bart.columns.to_list()
# Out:
# ['OBJECTID',
#  'LOCATION',
#  'STATION',
#  'CODE',
#  'ADDRESS',
#  'ZIP',
#  'PASS_OP',
#  'PASS_NETWO',
#  'COMM_OP',
#  'COMM_NETWO',
#  'BUS_ROUTES',
#  'TRANSIT',
#  'AIRPORT',
#  'STATION_TY',
#  'INTERMODAL',
#  'DIST',
#  'CO',
#  'geometry']

# %%
bart['CO'].value_counts()
# Out:
# LA     38
# ALA    30
# SM     19
# SCL    18
# RIV    17
# SF     17
# SBD    13
# CC     12
# ORA    11
# MON    11
# SB      9
# MPA     8
# SD      8
# VEN     8
# SJ      7
# HUM     6
# KIN     5
# SON     5
# SLO     5
# MEN     4
# KER     4
#         4
# PLA     4
# SAC     3
# SOL     3
# ED      3
# SCR     2
# NAP     2
# TUL     2
# STA     2
# BUT     2
# SHA     2
# YUB     1
# FRE     1
# YOL     1
# MAD     1
# MER     1
# NEV     1
# TEH     1
# SIS     1
# Name: CO, dtype: int64

# %% [markdown]
#  I found that there are 30 stops in Alameda County. Based on the columns I have in my other dataset, I know which ones I need to keep.

# %%
columns_to_keep = ['OBJECTID',
                   'LOCATION',
                   'STATION',
                   'CODE',
                   'ADDRESS',
                   'ZIP',
                   'COMM_NETWO',
                   'STATION_TY',
                   'DIST',
                   'CO',
                   'geometry']

# %%
bart2 = bart[columns_to_keep] #I created a new variable bart2 just so the original dataset doesn't get changed completely
bart2.sample(15)
# Out:
#      OBJECTID                  LOCATION                    STATION CODE  \
# 203       204                                              CAPITOL
# 51         52            Amtrak Station                 EMERYVILLE  EMY
# 180       181                                              22ND ST
# 277       278                                            Montclair
# 28         29                 Taco Bell                  RED BLUFF  RBF
# 121       122    Regional Trans. Center                  SANTA ANA  SNA
# 17         18            Amtrak Station                   DUNSMUIR  DUN
# 88         89  Amtrak/Metrolink Station                 CHATSWORTH  CWT
# 267       268                                       Pomona (North)
# 256       257                                  Carlsbad Poinsettia
# 118       119  Amtrak/Metrolink Station                  FULLERTON  FUL
# 262       263                            Norwalk/ Santa Fe Springs
# 189       190                                            HILLSDALE
# 150       151          Caltrain Station              SAN FRANCISCO  SFM
# 9          10       Yosemite - Ahwahnee                   YOSEMITE  YOA
#
#                        ADDRESS    ZIP  \
# 203                                 0
# 51             5885 Horton St.  94608
# 180                                 0
# 277                                 0
# 28                228 Main St.  96080
# 121       1000 Santa Ana Blvd.  92701
# 17        5750 Sacramento Ave.  96025
# 88   10040 Old Depot Plaza Rd.  91311
# 267                                 0
# 256                                 0
# 118       120 E. Santa Fe Ave.  92832
# 262                                 0
# 189                                 0
# 150      Howard St. at 4th St.  94103
# 9             1 Ahwahnee Drive  95389
#
#                                             COMM_NETWO  STATION_TY  DIST   CO  \
# 203                                           Caltrain           1     4  SCL
# 51                                                               5     4  ALA
# 180                                           Caltrain           1     4   SF
# 277                                San Bernardino Line           1     8  SBD
# 28                                                               2     2  TEH
# 121  Inland Empire-Orange County Line,Orange County...           8    12  ORA
# 17                                                               1     2  SIS
# 88                                 Ventura County Line           5     7   LA
# 267                                San Bernardino Line           1     7   LA
# 256                                            Coaster           1    11   SD
# 118                         91 Line,Orange County Line           5    12  ORA
# 262                         91 Line,Orange County Line           1     7   LA
# 189                                           Caltrain           1     4   SM
# 150                                                              2     4   SF
# 9                                                                2    10  MPA
#
#                         geometry
# 203  POINT (-121.84184 37.28393)
# 51   POINT (-122.29146 37.84053)
# 180  POINT (-122.39275 37.75736)
# 277  POINT (-117.69567 34.09392)
# 28   POINT (-122.23095 40.17270)
# 121  POINT (-117.85600 33.75150)
# 17   POINT (-122.27056 41.21245)
# 88   POINT (-118.59945 34.25292)
# 267  POINT (-117.75305 34.09357)
# 256  POINT (-117.31904 33.10875)
# 118  POINT (-117.92234 33.86869)
# 262  POINT (-118.06001 33.91623)
# 189  POINT (-122.29794 37.53800)
# 150  POINT (-122.40155 37.78414)
# 9    POINT (-119.57442 37.74668)

# %%
bart2 = bart2[bart2.CO == 'ALA'] #I'm only wanting to keep the rows that have "ALA" in the CO column
bart2.sample(10)
# Out:
#      OBJECTID                                           LOCATION  \
# 226       227
# 215       216
# 225       226
# 53         54  Across Mission Blvd. from Caltrans Park-n-Ride...
# 222       223
# 50         51                                     Amtrak Station
# 224       225
# 48         49                               LAVTA Transit Center
# 214       215
# 52         53                                       BART Station
#
#                             STATION CODE  \
# 226                         HAYWARD
# 215                       ROCKRIDGE
# 225                   CASTRO VALLEY
# 53         FREMONT/MISSION SAN JOSE  FRT
# 222  COLISEUM/OAKLAND AIRPORT (OAK)
# 50                          HAYWARD  HAY
# 224                        BAY FAIR
# 48                        LIVERMORE  LIV
# 214                           ASHBY
# 52                DUBLIN/PLEASANTON  DBP
#
#                                    ADDRESS    ZIP COMM_NETWO  STATION_TY  \
# 226                                             0       BART           1
# 215                                             0       BART           1
# 225                                             0       BART           1
# 53   Upper Mission Blvd (Hwy 238) at I-680  94538                      2
# 222                                             0       BART           1
# 50          22555 Meekland Ave. at "A" St.  94545                      4
# 224                                             0       BART           1
# 48       2500 Railroad Ave. (near 1st St.)  94550        ACE           3
# 214                                             0       BART           1
# 52      I-580 at Hopyard (Mid-Day Parking)  94588       BART           3
#
#      DIST   CO                     geometry
# 226     4  ALA  POINT (-122.08720 37.67012)
# 215     4  ALA  POINT (-122.25178 37.84451)
# 225     4  ALA  POINT (-122.07642 37.69072)
# 53      4  ALA  POINT (-121.92382 37.53955)
# 222     4  ALA  POINT (-122.19718 37.75386)
# 50      4  ALA  POINT (-122.09869 37.66666)
# 224     4  ALA  POINT (-122.12706 37.69757)
# 48      4  ALA  POINT (-121.76750 37.68501)
# 214     4  ALA  POINT (-122.27012 37.85321)
# 52      4  ALA  POINT (-121.89849 37.70247)

# %%
bart2['STATION'].value_counts()
# Out:
# HAYWARD                           2
# OAKLAND COLISEUM                  1
# MACARTHUR                         1
# FREMONT                           1
# UNION CITY                        1
# SOUTH HAYWARD                     1
# CASTRO VALLEY                     1
# BAY FAIR                          1
# SAN LEANDRO                       1
# COLISEUM/OAKLAND AIRPORT (OAK)    1
# FRUITVALE                         1
# LAKE MERRITT                      1
# 12TH ST/OAKLAND CITY CENTER       1
# WEST OAKLAND                      1
# 19TH STREET/OAKLAND               1
# ROCKRIDGE                         1
# BERKELEY                          1
# ASHBY                             1
# DOWNTOWN BERKELEY                 1
# NORTH BERKELEY                    1
# PLEASANTON                        1
# VASCO ROAD                        1
# FREMONT/MISSION SAN JOSE          1
# DUBLIN/PLEASANTON                 1
# EMERYVILLE                        1
# OAKLAND                           1
# LIVERMORE                         1
# FREMONT/CENTERVILLE               1
# WEST DUBLIN/PLEASANTON            1
# Name: STATION, dtype: int64

# %% [markdown]
# Chaithra and I picked a few stations to focus on sice they were the ones who had TOD projects completed. They are Fruitvale Transit Village (Fruitvale BART-Oakland), Hayward Bart Station (Hayward), MacArthur BART station (Oakland), South Hayward BART station (Hayward), Ashby BART station (Berkeley).
#
# For our control stations (non TOD bart stations) I'm going to pick stations that fall in the same city as our TOD stations and are within two stops of our TOD stations to try to control for any geographical/socio-economic differences. I've decided on North Berkeley (Berkeley), 19th st/Oakland (Oakland), Lake Merrit (Oakland), Bay Fair (Next to Hayward), and Union City (next to S. Hayward).

# %%
bart2= bart2.set_index("STATION") #this is to set the station names as the index so it is easier to delete the rows I don't need
bart2.head()
# Out:
#                      OBJECTID              LOCATION CODE  \
# STATION
# OAKLAND COLISEUM            4        Amtrak Station  OAC
# BERKELEY                   47        Amtrak Station  BKY
# FREMONT/CENTERVILLE        48        Amtrak Station  FMT
# LIVERMORE                  49  LAVTA Transit Center  LIV
# OAKLAND                    50        Amtrak Station  OKJ
#
#                                                   ADDRESS    ZIP COMM_NETWO  \
# STATION
# OAKLAND COLISEUM                 700 Seventy-third Avenue  94621
# BERKELEY                        University Ave. & 3rd St.  94710
# FREMONT/CENTERVILLE  37260 Fremont Blvd. at Peralta Blvd.  94536        ACE
# LIVERMORE               2500 Railroad Ave. (near 1st St.)  94550        ACE
# OAKLAND                                       245 2nd St.  94607
#
#                      STATION_TY  DIST   CO                     geometry
# STATION
# OAKLAND COLISEUM              6     4  ALA  POINT (-122.19820 37.75252)
# BERKELEY                      4     4  ALA  POINT (-122.30087 37.86742)
# FREMONT/CENTERVILLE           5     4  ALA  POINT (-122.00735 37.55890)
# LIVERMORE                     3     4  ALA  POINT (-121.76750 37.68501)
# OAKLAND                       5     4  ALA  POINT (-122.27148 37.79415)

# %% [markdown]
# I needed to reset the index so I can use the .loc function and just copy and paste the station names without trying to find their original index number. Now I can use the .loc function to isolate the stations I need and create a variable with those stations.

# %%
bart2.loc[['ASHBY',
           'MACARTHUR',
           'HAYWARD',
           'SOUTH HAYWARD',
           'FRUITVALE',
           'NORTH BERKELEY',
           '19TH STREET/OAKLAND',
           'BAY FAIR',
          'UNION CITY',
           'LAKE MERRITT']
          ]
# Out:
#                      OBJECTID        LOCATION CODE  \
# STATION
# ASHBY                     215
# MACARTHUR                 217
# HAYWARD                    51  Amtrak Station  HAY
# HAYWARD                   227
# SOUTH HAYWARD             228
# FRUITVALE                 222
# NORTH BERKELEY            213
# 19TH STREET/OAKLAND       218
# BAY FAIR                  225
# UNION CITY                229
# LAKE MERRITT              221
#
#                                             ADDRESS    ZIP COMM_NETWO  \
# STATION
# ASHBY                                                    0       BART
# MACARTHUR                                                0       BART
# HAYWARD              22555 Meekland Ave. at "A" St.  94545
# HAYWARD                                                  0       BART
# SOUTH HAYWARD                                            0       BART
# FRUITVALE                                                0       BART
# NORTH BERKELEY                                           0       BART
# 19TH STREET/OAKLAND                                      0       BART
# BAY FAIR                                                 0       BART
# UNION CITY                                               0       BART
# LAKE MERRITT                                             0       BART
#
#                      STATION_TY  DIST   CO                     geometry
# STATION
# ASHBY                         1     4  ALA  POINT (-122.27012 37.85321)
# MACARTHUR                     1     4  ALA  POINT (-122.26712 37.82871)
# HAYWARD                       4     4  ALA  POINT (-122.09869 37.66666)
# HAYWARD                       1     4  ALA  POINT (-122.08720 37.67012)
# SOUTH HAYWARD                 1     4  ALA  POINT (-122.05704 37.63448)
# FRUITVALE                     1     4  ALA  POINT (-122.22420 37.77456)
# NORTH BERKELEY                1     4  ALA  POINT (-122.28335 37.87406)
# 19TH STREET/OAKLAND           1     4  ALA  POINT (-122.26839 37.80808)
# BAY FAIR                      1     4  ALA  POINT (-122.12706 37.69757)
# UNION CITY                    1     4  ALA  POINT (-122.01715 37.59087)
# LAKE MERRITT                  1     4  ALA  POINT (-122.26554 37.79768)

# %%
stations = bart2.loc[['ASHBY',
           'MACARTHUR',
           'HAYWARD',
           'SOUTH HAYWARD',
           'FRUITVALE',
           'NORTH BERKELEY',
           '19TH STREET/OAKLAND',
           'BAY FAIR',
          'UNION CITY',
           'LAKE MERRITT']
          ]
stations.head()
# Out:
#                OBJECTID        LOCATION CODE                         ADDRESS  \
# STATION
# ASHBY               215
# MACARTHUR           217
# HAYWARD              51  Amtrak Station  HAY  22555 Meekland Ave. at "A" St.
# HAYWARD             227
# SOUTH HAYWARD       228
#
#                  ZIP COMM_NETWO  STATION_TY  DIST   CO  \
# STATION
# ASHBY              0       BART           1     4  ALA
# MACARTHUR          0       BART           1     4  ALA
# HAYWARD        94545                      4     4  ALA
# HAYWARD            0       BART           1     4  ALA
# SOUTH HAYWARD      0       BART           1     4  ALA
#
#                                   geometry
# STATION
# ASHBY          POINT (-122.27012 37.85321)
# MACARTHUR      POINT (-122.26712 37.82871)
# HAYWARD        POINT (-122.09869 37.66666)
# HAYWARD        POINT (-122.08720 37.67012)
# SOUTH HAYWARD  POINT (-122.05704 37.63448)

# %% [markdown]
# I created a new variable with just our stations of focus. However I see there are two Haywards, so I'll get rid of the one we don't need.

# %%
stations = stations[stations.COMM_NETWO == 'BART']
stations.head(11)
# Out:
#                      OBJECTID LOCATION CODE ADDRESS ZIP COMM_NETWO  \
# STATION
# ASHBY                     215                         0       BART
# MACARTHUR                 217                         0       BART
# HAYWARD                   227                         0       BART
# SOUTH HAYWARD             228                         0       BART
# FRUITVALE                 222                         0       BART
# NORTH BERKELEY            213                         0       BART
# 19TH STREET/OAKLAND       218                         0       BART
# BAY FAIR                  225                         0       BART
# UNION CITY                229                         0       BART
# LAKE MERRITT              221                         0       BART
#
#                      STATION_TY  DIST   CO                     geometry
# STATION
# ASHBY                         1     4  ALA  POINT (-122.27012 37.85321)
# MACARTHUR                     1     4  ALA  POINT (-122.26712 37.82871)
# HAYWARD                       1     4  ALA  POINT (-122.08720 37.67012)
# SOUTH HAYWARD                 1     4  ALA  POINT (-122.05704 37.63448)
# FRUITVALE                     1     4  ALA  POINT (-122.22420 37.77456)
# NORTH BERKELEY                1     4  ALA  POINT (-122.28335 37.87406)
# 19TH STREET/OAKLAND           1     4  ALA  POINT (-122.26839 37.80808)
# BAY FAIR                      1     4  ALA  POINT (-122.12706 37.69757)
# UNION CITY                    1     4  ALA  POINT (-122.01715 37.59087)
# LAKE MERRITT                  1     4  ALA  POINT (-122.26554 37.79768)

# %% [markdown]
# Now I'm going to reset the index. This will help me later when I'm using my function and loop. I will also refine my columns so that I only have the necessary ones.

# %%
stations = stations.reset_index()
stations.head()
# Out:
#          STATION  OBJECTID LOCATION CODE ADDRESS ZIP COMM_NETWO  STATION_TY  \
# 0          ASHBY       215                         0       BART           1
# 1      MACARTHUR       217                         0       BART           1
# 2        HAYWARD       227                         0       BART           1
# 3  SOUTH HAYWARD       228                         0       BART           1
# 4      FRUITVALE       222                         0       BART           1
#
#    DIST   CO                     geometry
# 0     4  ALA  POINT (-122.27012 37.85321)
# 1     4  ALA  POINT (-122.26712 37.82871)
# 2     4  ALA  POINT (-122.08720 37.67012)
# 3     4  ALA  POINT (-122.05704 37.63448)
# 4     4  ALA  POINT (-122.22420 37.77456)

# %%
list(stations)
# Out:
# ['STATION',
#  'OBJECTID',
#  'LOCATION',
#  'CODE',
#  'ADDRESS',
#  'ZIP',
#  'COMM_NETWO',
#  'STATION_TY',
#  'DIST',
#  'CO',
#  'geometry']

# %%
keep = ['STATION',
        'LOCATION',
        'CODE',
        'COMM_NETWO',
        'CO',
        'geometry']

# %%
stations = stations[keep]
stations.head(10)
# Out:
#                STATION LOCATION CODE COMM_NETWO   CO  \
# 0                ASHBY                     BART  ALA
# 1            MACARTHUR                     BART  ALA
# 2              HAYWARD                     BART  ALA
# 3        SOUTH HAYWARD                     BART  ALA
# 4            FRUITVALE                     BART  ALA
# 5       NORTH BERKELEY                     BART  ALA
# 6  19TH STREET/OAKLAND                     BART  ALA
# 7             BAY FAIR                     BART  ALA
# 8           UNION CITY                     BART  ALA
# 9         LAKE MERRITT                     BART  ALA
#
#                       geometry
# 0  POINT (-122.27012 37.85321)
# 1  POINT (-122.26712 37.82871)
# 2  POINT (-122.08720 37.67012)
# 3  POINT (-122.05704 37.63448)
# 4  POINT (-122.22420 37.77456)
# 5  POINT (-122.28335 37.87406)
# 6  POINT (-122.26839 37.80808)
# 7  POINT (-122.12706 37.69757)
# 8  POINT (-122.01715 37.59087)
# 9  POINT (-122.26554 37.79768)

# %% [markdown]
# Now I'm going to fill in the Location and Code. I'll do this by using .loc again

# %%
stations.loc[0:9,['LOCATION']] = ['Berkeley',
                                  'Oakland',
                                  'Hayward',
                                 'Hayward',
                                 'Oakland',
                                 'Berkeley',
                                 'Oakland',
                                 'San Leandro',
                                 'Union City',
                                 'Oakland']

# %%
stations.head(10)
# Out:
#                STATION     LOCATION CODE COMM_NETWO   CO  \
# 0                ASHBY     Berkeley            BART  ALA
# 1            MACARTHUR      Oakland            BART  ALA
# 2              HAYWARD      Hayward            BART  ALA
# 3        SOUTH HAYWARD      Hayward            BART  ALA
# 4            FRUITVALE      Oakland            BART  ALA
# 5       NORTH BERKELEY     Berkeley            BART  ALA
# 6  19TH STREET/OAKLAND      Oakland            BART  ALA
# 7             BAY FAIR  San Leandro            BART  ALA
# 8           UNION CITY   Union City            BART  ALA
# 9         LAKE MERRITT      Oakland            BART  ALA
#
#                       geometry
# 0  POINT (-122.27012 37.85321)
# 1  POINT (-122.26712 37.82871)
# 2  POINT (-122.08720 37.67012)
# 3  POINT (-122.05704 37.63448)
# 4  POINT (-122.22420 37.77456)
# 5  POINT (-122.28335 37.87406)
# 6  POINT (-122.26839 37.80808)
# 7  POINT (-122.12706 37.69757)
# 8  POINT (-122.01715 37.59087)
# 9  POINT (-122.26554 37.79768)

# %% [markdown]
# Great! Now I'm going to fill in the code column so that it has an abbreviation of the location.

# %%
stations.loc[stations.LOCATION == "Berkeley", "CODE"] = "BKY"
stations.loc[stations.LOCATION == "Oakland", "CODE"] = "OAK"
stations.loc[stations.LOCATION == "Hayward", "CODE"] = "HAY"
stations.loc[stations.LOCATION == "Union City", "CODE"] = "UNC"
stations.loc[stations.LOCATION == "San Leandro", "CODE"] = "SAN"
stations.head(10)
# Out:
#                STATION     LOCATION CODE COMM_NETWO   CO  \
# 0                ASHBY     Berkeley  BKY       BART  ALA
# 1            MACARTHUR      Oakland  OAK       BART  ALA
# 2              HAYWARD      Hayward  HAY       BART  ALA
# 3        SOUTH HAYWARD      Hayward  HAY       BART  ALA
# 4            FRUITVALE      Oakland  OAK       BART  ALA
# 5       NORTH BERKELEY     Berkeley  BKY       BART  ALA
# 6  19TH STREET/OAKLAND      Oakland  OAK       BART  ALA
# 7             BAY FAIR  San Leandro  SAN       BART  ALA
# 8           UNION CITY   Union City  UNC       BART  ALA
# 9         LAKE MERRITT      Oakland  OAK       BART  ALA
#
#                       geometry
# 0  POINT (-122.27012 37.85321)
# 1  POINT (-122.26712 37.82871)
# 2  POINT (-122.08720 37.67012)
# 3  POINT (-122.05704 37.63448)
# 4  POINT (-122.22420 37.77456)
# 5  POINT (-122.28335 37.87406)
# 6  POINT (-122.26839 37.80808)
# 7  POINT (-122.12706 37.69757)
# 8  POINT (-122.01715 37.59087)
# 9  POINT (-122.26554 37.79768)

# %% [markdown]
# It worked! In the code I used above, I used the .loc function to change values in the Code column if they were equal to some value specific value in the Location column. So if Location= Berkeley, the code column would update any value that matched the location command. This saves me time because there are multiple duplicates in the dataset.
#
# Now I'm going to make a new column to signify if that particular station is a TOD project location or not. For simplicities sake, I'm going to just rename the comm_netwo column and add the values in there. I'm realizing that column really isn't that useful as it is. Plus, this way I can rename all the columns to make them better anyway.

# %%
stations.columns = ['Station',
                    'City',
                    'Code',
                    'TOD',
                    'County',
                    'geometry']
stations.head(10)
# Out:
#                Station         City Code   TOD County  \
# 0                ASHBY     Berkeley  BKY  BART    ALA
# 1            MACARTHUR      Oakland  OAK  BART    ALA
# 2              HAYWARD      Hayward  HAY  BART    ALA
# 3        SOUTH HAYWARD      Hayward  HAY  BART    ALA
# 4            FRUITVALE      Oakland  OAK  BART    ALA
# 5       NORTH BERKELEY     Berkeley  BKY  BART    ALA
# 6  19TH STREET/OAKLAND      Oakland  OAK  BART    ALA
# 7             BAY FAIR  San Leandro  SAN  BART    ALA
# 8           UNION CITY   Union City  UNC  BART    ALA
# 9         LAKE MERRITT      Oakland  OAK  BART    ALA
#
#                       geometry
# 0  POINT (-122.27012 37.85321)
# 1  POINT (-122.26712 37.82871)
# 2  POINT (-122.08720 37.67012)
# 3  POINT (-122.05704 37.63448)
# 4  POINT (-122.22420 37.77456)
# 5  POINT (-122.28335 37.87406)
# 6  POINT (-122.26839 37.80808)
# 7  POINT (-122.12706 37.69757)
# 8  POINT (-122.01715 37.59087)
# 9  POINT (-122.26554 37.79768)

# %%
stations.loc[0:4,['TOD']] = ['Yes'] #this changes all the values from 0-4 to Yes in the TOD column because all of these are TOD
stations.loc[5:9,['TOD']] = ['No'] #the rest are not TOD

# %%
stations.head(10)
# Out:
#                Station         City Code  TOD County  \
# 0                ASHBY     Berkeley  BKY  Yes    ALA
# 1            MACARTHUR      Oakland  OAK  Yes    ALA
# 2              HAYWARD      Hayward  HAY  Yes    ALA
# 3        SOUTH HAYWARD      Hayward  HAY  Yes    ALA
# 4            FRUITVALE      Oakland  OAK  Yes    ALA
# 5       NORTH BERKELEY     Berkeley  BKY   No    ALA
# 6  19TH STREET/OAKLAND      Oakland  OAK   No    ALA
# 7             BAY FAIR  San Leandro  SAN   No    ALA
# 8           UNION CITY   Union City  UNC   No    ALA
# 9         LAKE MERRITT      Oakland  OAK   No    ALA
#
#                       geometry
# 0  POINT (-122.27012 37.85321)
# 1  POINT (-122.26712 37.82871)
# 2  POINT (-122.08720 37.67012)
# 3  POINT (-122.05704 37.63448)
# 4  POINT (-122.22420 37.77456)
# 5  POINT (-122.28335 37.87406)
# 6  POINT (-122.26839 37.80808)
# 7  POINT (-122.12706 37.69757)
# 8  POINT (-122.01715 37.59087)
# 9  POINT (-122.26554 37.79768)

# %% [markdown]
# Great! Now I'm going to make a column "marker" column so that we can distinguish between the TOD and non TOD stations on a map.

# %%
stations['Marker']= "x"
stations.head()
# Out:
#          Station      City Code  TOD County                     geometry  \
# 0          ASHBY  Berkeley  BKY  Yes    ALA  POINT (-122.27012 37.85321)
# 1      MACARTHUR   Oakland  OAK  Yes    ALA  POINT (-122.26712 37.82871)
# 2        HAYWARD   Hayward  HAY  Yes    ALA  POINT (-122.08720 37.67012)
# 3  SOUTH HAYWARD   Hayward  HAY  Yes    ALA  POINT (-122.05704 37.63448)
# 4      FRUITVALE   Oakland  OAK  Yes    ALA  POINT (-122.22420 37.77456)
#
#   Marker
# 0      x
# 1      x
# 2      x
# 3      x
# 4      x

# %%
stations.loc[stations.TOD == "Yes", "Marker"] = "D" #marker symbol of a diamond
stations.loc[stations.TOD == "No", "Marker"] = "o" #marker symbol of a circle
stations.head()
# Out:
#          Station      City Code  TOD County                     geometry  \
# 0          ASHBY  Berkeley  BKY  Yes    ALA  POINT (-122.27012 37.85321)
# 1      MACARTHUR   Oakland  OAK  Yes    ALA  POINT (-122.26712 37.82871)
# 2        HAYWARD   Hayward  HAY  Yes    ALA  POINT (-122.08720 37.67012)
# 3  SOUTH HAYWARD   Hayward  HAY  Yes    ALA  POINT (-122.05704 37.63448)
# 4      FRUITVALE   Oakland  OAK  Yes    ALA  POINT (-122.22420 37.77456)
#
#   Marker
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D

# %%
stations.to_file("stations.geojson", driver='GeoJSON')

# %% [markdown]
# In the code above I saved the geodataframe so that I can send it to Chaithra and use it for later projects.

# %% [markdown]
# Now let us create fuctions to display if a particualr station is TOD or not. We will do this step-by-step. First a function to see how this might work.

# %%
def TOD(location):
    print(location + ' ' + 'is a TOD station in Alameda County California.')

# %%
TOD_stations = ['Ashby', 'MacArthur', 'Hayward', 'South Hayward', 'Fruitvale']

# %%
for station in TOD_stations:
    TOD(location=station)
# Out:
# Ashby is a TOD station in Alameda County California.
# MacArthur is a TOD station in Alameda County California.
# Hayward is a TOD station in Alameda County California.
# South Hayward is a TOD station in Alameda County California.
# Fruitvale is a TOD station in Alameda County California.

# %% [markdown]
# That works perfectly. Now a little bit more refined fuction. Here we will input index for a row and then check if station is TOD or not. We will then call this fuction via a loop.

# %%
def TODcheck(s):
    if stations.iloc[s] ["TOD"]=="Yes":
        print(stations.iloc[s,0],"is a TOD Station.")
    else:
        print(stations.iloc[s,0],"is not a TOD Station.")

# %%
for i in stations.index:
    TODcheck(i)
# Out:
# ASHBY is a TOD Station.
# MACARTHUR is a TOD Station.
# HAYWARD is a TOD Station.
# SOUTH HAYWARD is a TOD Station.
# FRUITVALE is a TOD Station.
# NORTH BERKELEY is not a TOD Station.
# 19TH STREET/OAKLAND is not a TOD Station.
# BAY FAIR is not a TOD Station.
# UNION CITY is not a TOD Station.
# LAKE MERRITT is not a TOD Station.

# %% [markdown]
# This gives TOD status of each station.

# %%
stations.head(10)
# Out:
#                Station         City Code  TOD County  \
# 0                ASHBY     Berkeley  BKY  Yes    ALA
# 1            MACARTHUR      Oakland  OAK  Yes    ALA
# 2              HAYWARD      Hayward  HAY  Yes    ALA
# 3        SOUTH HAYWARD      Hayward  HAY  Yes    ALA
# 4            FRUITVALE      Oakland  OAK  Yes    ALA
# 5       NORTH BERKELEY     Berkeley  BKY   No    ALA
# 6  19TH STREET/OAKLAND      Oakland  OAK   No    ALA
# 7             BAY FAIR  San Leandro  SAN   No    ALA
# 8           UNION CITY   Union City  UNC   No    ALA
# 9         LAKE MERRITT      Oakland  OAK   No    ALA
#
#                       geometry Marker
# 0  POINT (-122.27012 37.85321)      D
# 1  POINT (-122.26712 37.82871)      D
# 2  POINT (-122.08720 37.67012)      D
# 3  POINT (-122.05704 37.63448)      D
# 4  POINT (-122.22420 37.77456)      D
# 5  POINT (-122.28335 37.87406)      o
# 6  POINT (-122.26839 37.80808)      o
# 7  POINT (-122.12706 37.69757)      o
# 8  POINT (-122.01715 37.59087)      o
# 9  POINT (-122.26554 37.79768)      o
